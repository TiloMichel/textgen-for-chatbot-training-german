# %%
# %%capture
# !pip install transformers datasets sentencepiece

# %%
# !git clone https://github.com/TiloMichel/textgen-for-chatbot-training-german.git
# Out:
# Cloning into 'textgen-for-chatbot-training-german'...
# remote: Enumerating objects: 132, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 132 (delta 1), reused 15 (delta 1), pack-reused 112
# Receiving objects: 100% (132/132), 4.82 MiB | 10.48 MiB/s, done.
# Resolving deltas: 100% (16/16), done.

# %%
# %cd /content/textgen-for-chatbot-training-german/2_training
# Out:
# /content/textgen-for-chatbot-training-german/2_training

# %% [markdown]
# Create a dataset with https://colab.research.google.com/github/TiloMichel/textgen-for-chatbot-training-german/blob/main/1_data_preparation_and_exploration/create_qg_dataset.ipynb
#
# Upload created dataset as zip

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-de3792d5-763e-4da6-8389-78647b7268c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-de3792d5-763e-4da6-8389-78647b7268c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving e2e-qg-germanquad.zip to e2e-qg-germanquad.zip

# %% [markdown]
# Unzip created dataset

# %%
# !mkdir e2e-qg-germanquad
# !unzip e2e-qg-germanquad.zip -d e2e-qg-germanquad
# Out:
# Archive:  e2e-qg-germanquad.zip
#    creating: e2e-qg-germanquad/train/
#    creating: e2e-qg-germanquad/validation/
#   inflating: e2e-qg-germanquad/dataset_dict.json
#   inflating: e2e-qg-germanquad/validation/dataset_info.json
#   inflating: e2e-qg-germanquad/validation/state.json
#   inflating: e2e-qg-germanquad/validation/dataset.arrow
#   inflating: e2e-qg-germanquad/train/dataset_info.json
#   inflating: e2e-qg-germanquad/train/state.json
#   inflating: e2e-qg-germanquad/train/dataset.arrow

# %% [markdown]
# Training

# %%
# !python run_text2text.py configs/M-1-mt5-e2e-qg-germanquad.json
# Out:
# 07/02/2022 13:05:48 - WARNING - __main__ -   Process rank: -1, device: cuda:0, n_gpu: 1 distributed training: False, 16-bits training: False
# 07/02/2022 13:05:48 - INFO - __main__ -   Training/evaluation parameters Seq2SeqTrainingArguments(
# _n_gpu=1,
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# bf16=False,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=8,
# dataloader_pin_memory=True,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=False,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_steps=None,
# evaluation_strategy=IntervalStrategy.EPOCH,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_min_num_params=0,
# full_determinism=False,
# generation_max_length=None,
# generation_num_beams=None,
# ...
